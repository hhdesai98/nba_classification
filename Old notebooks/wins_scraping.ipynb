# %%
import pandas as pd
import numpy as np
import time

# %%
wins
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 wins
#
# NameError: name 'wins' is not defined

# %%
df
# Out:
#    Team   W   L   W/L%    GB   PS/G   PA/G   SRS
# 0   MIL  58  24  0.707     —  116.9  113.3  3.61
# 1   BOS  57  25  0.695   1.0  117.9  111.4  6.38
# 2   PHI  54  28  0.659   4.0  115.2  110.9  4.37
# 3   CLE  51  31  0.622   7.0  112.3  106.9  5.23
# 4   NYK  47  35  0.573  11.0  116.0  113.1  2.99
# 5   BKN  45  37  0.549  13.0  113.4  112.5  1.03
# 6   MIA  44  38  0.537  14.0  109.5  109.8 -0.13
# 7   ATL  41  41  0.500  17.0  118.4  118.1  0.32
# 8   TOR  41  41  0.500  17.0  112.9  111.4  1.59
# 9   CHI  40  42  0.488  18.0  113.1  111.8  1.37
# 10  IND  35  47  0.427  23.0  116.3  119.5 -2.91
# 11  WAS  35  47  0.427  23.0  113.2  114.4 -1.06
# 12  ORL  34  48  0.415  24.0  111.4  114.0 -2.39
# 13  CHA  27  55  0.329  31.0  111.0  117.2 -5.89
# 14  DET  17  65  0.207  41.0  110.3  118.5 -7.73
# 0   DEN  53  29  0.646     —  115.8  112.5  3.04
# 1   MEM  51  31  0.622   2.0  116.9  113.0  3.60
# 2   SAC  48  34  0.585   5.0  120.7  118.1  2.30
# ...
